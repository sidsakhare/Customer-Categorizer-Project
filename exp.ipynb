# %%
import numpy as np
import pandas as pd

file_path = r'C:\Users\ACER\OneDrive\Desktop\ML Notes and colab Notebooks\Data Science Projects\Customer-Categorization-new\src\artifact\data_transformation\transformed\test.npz'

data = np.load(file_path)

print(type(data))
print(data.shape)
print(data.dtype)
print(data)

dataframe = pd.DataFrame(data)
# Out:
# <class 'numpy.ndarray'>
# (447, 22)
# float64
# [[-0.67444807 -1.35634897  0.64100178 ...  0.46169681  0.66502498
#    2.        ]
#  [ 1.67071732  0.73727339  0.64100178 ...  0.21078796  1.25952142
#    1.        ]
#  [-0.67444807 -1.35634897  0.64100178 ...  1.19055318  0.32128795
#    2.        ]
#  ...
#  [ 0.49813463  0.73727339  0.64100178 ...  0.29490125 -1.02268224
#    0.        ]
#  [ 1.67071732 -1.35634897 -1.56005807 ...  1.73558475  1.05733879
#    1.        ]
#  [ 1.67071732  0.73727339  0.64100178 ...  0.87079887 -1.1964134
#    0.        ]]

# %%
dataframe
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.674448 -1.356349  0.641002  0.078081 -0.004599  1.560144  1.598304
# 1    1.670717  0.737273  0.641002  0.078081  1.200941  0.686019  1.667379
# 2   -0.674448 -1.356349  0.641002  0.078081 -0.482177  0.730974 -0.612101
# 3   -0.674448  0.737273  0.641002  1.408426  1.087041  1.390314  1.563767
# 4    0.498135 -1.356349  0.641002  1.408426 -0.655880 -1.476818 -0.853864
# ..        ...       ...       ...       ...       ...       ...       ...
# 442  0.498135  0.737273  0.641002  0.078081 -0.296691 -0.073222  1.494691
# 443  1.670717  0.737273  0.641002  0.078081 -0.671637  1.140564 -0.612101
# 444  0.498135  0.737273  0.641002  0.078081 -0.288883 -1.436858  1.080241
# 445  1.670717 -1.356349 -1.560058 -1.252265  1.400407 -1.346948  0.182263
# 446  1.670717  0.737273  0.641002  1.408426 -0.717693 -0.862432  0.769402
#
#            7         8         9   ...        12        13        14  \
# ...
